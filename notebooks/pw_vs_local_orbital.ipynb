# %%
# Let's read in the Carbon example provided by Sandia
import numpy as np
from mec_sandia.vasp_utils import read_vasp

ase_cell = read_vasp(f"../vasp_data/C_POSCAR")

# %%
print(ase_cell)
# Out:
# Atoms(symbols='C128H', pbc=True, cell=[10.069796240332069, 5.0348981201660346, 5.0348981201660346], masses=...)

# %%
import pyscf.pbc.tools.pyscf_ase as pyscf_ase
from pyscf.pbc import gto

atom = pyscf_ase.ase_atoms_to_pyscf(ase_cell)

a = ase_cell.cell.array
print(a)

volume_ang = ase_cell.get_volume()
print("Volume = {} A^3".format(volume_ang))

cell = gto.M(a = a,
             atom = atom,
             basis = 'gth-szv',
             pseudo = 'gth-pade',
             unit='angstrom',
             verbose = 4,
             # ke_cutoff = 10 / 27.21138602, # in atomic units. This would be 10 eV in atomic units
             precision = 1.0e-8,
             charge = 0,
             spin = 1,
             dimension = 3)
from ase.units import Bohr
volume_bohr = volume_ang / Bohr**3
# and the number of valence electrons
num_carbon = len(np.where(ase_cell.get_atomic_numbers() == 6)[0])
# There is 1 hydrogen atom in the cell. Is this just a proton?
num_elec = 1 + num_carbon * 4 # pseudized 1s of carbon
from mec_sandia.vasp_utils import compute_wigner_seitz_radius
# Get the Wigner-Seitz radius
rs = compute_wigner_seitz_radius(volume_bohr, num_elec)
print("rs = {} bohr".format(rs))
print("eta = {} ".format(num_elec))
print("There should be 127 carbon + 1 phydrogen so 4 * 128 + 1 = ", 4 * 128 + 1)
print(cell.nelectron)
# Out:
# [[10.06979624  0.          0.        ]
#  [ 0.          5.03489812  0.        ]
#  [ 0.          0.          5.03489812]]
# Volume = 255.27133939199965 A^3
# System: uname_result(system='Linux', node='qlobster.c.googlers.com', release='5.19.11-1rodete1-amd64', version='#1 SMP PREEMPT_DYNAMIC Debian 5.19.11-1rodete1 (2022-10-31)', machine='x86_64')  Threads 96
# Python 3.9.15 | packaged by conda-forge | (main, Nov 22 2022, 15:55:03)
# [GCC 10.4.0]
# numpy 1.22.3  scipy 1.9.3
# Date: Mon Mar 20 13:10:14 2023
# PySCF version 2.1.0
# PySCF path  /usr/local/google/home/nickrubin/anaconda3/envs/thc-dev-eugene/lib/python3.9/site-packages/pyscf
#
# [CONFIG] conf_file None
# [INPUT] verbose = 4
# [INPUT] num. atoms = 129
# [INPUT] num. electrons = 513
# [INPUT] charge = 0
# [INPUT] spin (= nelec alpha-beta = 2S) = 1
# [INPUT] symmetry False subgroup None
# [INPUT] Mole.unit = angstrom
# [INPUT] Symbol           X                Y                Z      unit          X                Y                Z       unit  Magmom
# [INPUT]  1 H      6.213892690000   1.921017700000   4.623135460000 AA   11.742555351537   3.630197333442   8.736459856165 Bohr   0.0
# [INPUT]  2 C      8.347282217828   3.871208015769  -3.995452371562 AA   15.774077276146   7.315522921024  -7.550310725996 Bohr   0.0
# [INPUT]  3 C      2.858955394438   3.749930276474   5.037184323550 AA    5.402642697836   7.086341208750   9.518898810462 Bohr   0.0
# [INPUT]  4 C      4.905852945580  -1.458344169398   0.497299461400 AA    9.270718474536  -2.755871075518   0.939759783939 Bohr   0.0
# [INPUT]  5 C     -3.300863255226   1.683328103109   1.562003510003 AA   -6.237727527017   3.181029092660   2.951758839515 Bohr   0.0
# [INPUT]  6 C     13.071142706491   0.580903033486   1.699964671581 AA   24.700879850374   1.097747638218   3.212467650725 Bohr   0.0
# [INPUT]  7 C      3.390855112461   2.920934698803  -0.500750331366 AA    6.407787490633   5.519766608477  -0.946280983067 Bohr   0.0
# [INPUT]  8 C      0.360172515630   4.248292965968  10.226432150350 AA    0.680627412136   8.028110202596  19.325155995608 Bohr   0.0
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
# nuclear repulsion = -1194.96308336577
# number of shells = 257
# number of NR pGTOs = 2052
# number of NR cGTOs = 513
# basis = gth-szv
# ecp = {}
# CPU time:       110.30
# lattice vectors  a1 [19.029157024, 0.000000000, 0.000000000]
#                  a2 [0.000000000, 9.514578512, 0.000000000]
#                  a3 [0.000000000, 0.000000000, 9.514578512]
# dimension = 3
# low_dim_ft_type = None
# Cell volume = 1722.66
# rcut = 23.02739253532953 (nimgs = [2 3 3])
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
# lattice sum = 239 cells
# precision = 1e-08
# pseudo = gth-pade
# ke_cutoff = 335.11610367308435
#     = [157  79  79] mesh (979837 PWs)
# rs = 0.9289611708818379 bohr
# eta = 513
# There should be 127 carbon + 1 phydrogen so 4 * 128 + 1 =  513
# 513

# %%
from pyscf.pbc.dft import uks
ks = uks.UKS(cell)# .rs_density_fit()
ks.verbose = 4
ks.chkfile = 'UKS_C_POSCAR.chk'

# %%
ks.run()
# Out:
# Uniform grid, mesh = [157  79  79]
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
#
#
# WARN: Atoms found very far from the primitive cell. Atom coordinates may be error.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 ks.run()
#
# File ~/anaconda3/envs/thc-dev-eugene/lib/python3.9/site-packages/pyscf/lib/misc.py:534, in StreamObject.run(self, *args, **kwargs)
#     527 '''
#     528 Call the kernel function of current object.  `args` will be passed
#     529 to kernel function.  `kwargs` will be used to update the attributes of
#     530 current object.  The return value of method run is the object itself.
#     531 This allows a series of functions/methods to be executed in pipe.
#     532 '''
#     533 self.set(**kwargs)
# --> 534 self.kernel(*args)
#     535 return self
#
# File <string>:2, in kernel(self, dm0, **kwargs)
#
# File ~/anaconda3/envs/thc-dev-eugene/lib/python3.9/site-packages/pyscf/scf/hf.py:1692, in SCF.scf(self, dm0, **kwargs)
#    1687 self.build(self.mol)
#    1689 if self.max_cycle > 0 or self.mo_coeff is None:
#    1690     self.converged, self.e_tot, \
#    1691             self.mo_energy, self.mo_coeff, self.mo_occ = \
# -> 1692             kernel(self, self.conv_tol, self.conv_tol_grad,
#    1693                    dm0=dm0, callback=self.callback,
#    1694                    conv_check=self.conv_check, **kwargs)
#    1695 else:
#    1696     # Avoid to update SCF orbitals in the non-SCF initialization
#    1697     # (issue #495).  But run regular SCF for initial guess if SCF was
#    1698     # not initialized.
#    1699     self.e_tot = kernel(self, self.conv_tol, self.conv_tol_grad,
#    1700                         dm0=dm0, callback=self.callback,
#    1701                         conv_check=self.conv_check, **kwargs)[1]
#
# File ~/anaconda3/envs/thc-dev-eugene/lib/python3.9/site-packages/pyscf/scf/hf.py:128, in kernel(mf, conv_tol, conv_tol_grad, dump_chk, dm0, callback, conv_check, **kwargs)
#     125     dm = dm0
#     127 h1e = mf.get_hcore(mol)
# --> 128 vhf = mf.get_veff(mol, dm)
#     129 e_tot = mf.energy_tot(dm, h1e, vhf)
#     130 logger.info(mf, 'init E= %.15g', e_tot)
#
# File ~/anaconda3/envs/thc-dev-eugene/lib/python3.9/site-packages/pyscf/pbc/dft/uks.py:78, in get_veff(ks, cell, dm, dm_last, vhf_last, hermi, kpt, kpts_band)
#      76     n, exc, vxc = (0,0), 0, 0
#      77 else:
# ---> 78     n, exc, vxc = ks._numint.nr_uks(cell, ks.grids, ks.xc, dm, hermi,
#      79                                     kpt, kpts_band)
#      80     logger.debug(ks, 'nelec by numeric integration = %s', n)
#      81     t0 = logger.timer(ks, 'vxc', *t0)
#
# File ~/anaconda3/envs/thc-dev-eugene/lib/python3.9/site-packages/pyscf/pbc/dft/numint.py:932, in NumInt.nr_uks(self, cell, grids, xc_code, dms, hermi, kpt, kpts_band, max_memory, verbose)
#     928     nao = dms[0].shape[-1]
#     929     return ni.nr_uks(cell, grids, xc_code, dms.reshape(-1,1,nao,nao),
#     930                      hermi, kpt.reshape(1,3), kpts_band, max_memory,
#     931                      verbose)
# --> 932 return nr_uks(self, cell, grids, xc_code, dms,
#     933               1, 0, hermi, kpt, kpts_band, max_memory, verbose)
#
# File ~/anaconda3/envs/thc-dev-eugene/lib/python3.9/site-packages/pyscf/pbc/dft/numint.py:465, in nr_uks(ni, cell, grids, xc_code, dms, spin, relativity, hermi, kpts, kpts_band, max_memory, verbose)
#     463 vmatb = [0]*nset
#     464 v_hermi = 1  # the output matrix must be hermitian
# --> 465 for ao_k1, ao_k2, mask, weight, coords \
#     466         in ni.block_loop(cell, grids, nao, ao_deriv, kpts, kpts_band, max_memory):
#     467     for i in range(nset):
#     468         rho_a = make_rhoa(i, ao_k2, mask, xctype)
#
# File ~/anaconda3/envs/thc-dev-eugene/lib/python3.9/site-packages/pyscf/pbc/dft/numint.py:991, in NumInt.block_loop(self, cell, grids, nao, deriv, kpt, kpts_band, max_memory, non0tab, blksize)
#     989 weight = grids_weights[ip0:ip1]
#     990 non0 = non0tab[ip0//BLKSIZE:]
# --> 991 ao_k2 = self.eval_ao(cell, coords, kpt2, deriv=deriv, non0tab=non0,
#     992                      cutoff=grids.cutoff)
#     993 if abs(kpt1-kpt2).sum() < 1e-9:
#     994     ao_k1 = ao_k2
#
# File ~/anaconda3/envs/thc-dev-eugene/lib/python3.9/site-packages/pyscf/pbc/dft/numint.py:64, in eval_ao(cell, coords, kpt, deriv, relativity, shls_slice, non0tab, cutoff, out, verbose)
#      32 def eval_ao(cell, coords, kpt=numpy.zeros(3), deriv=0, relativity=0, shls_slice=None,
#      33             non0tab=None, cutoff=None, out=None, verbose=None):
#      34     '''Collocate AO crystal orbitals (opt. gradients) on the real-space grid.
#      35
#      36     Args:
#    (...)
#      62
#      63     '''
# ---> 64     ao_kpts = eval_ao_kpts(cell, coords, numpy.reshape(kpt, (-1,3)), deriv,
#      65                            relativity, shls_slice, non0tab, cutoff, out, verbose)
#      66     return ao_kpts[0]
#
# File ~/anaconda3/envs/thc-dev-eugene/lib/python3.9/site-packages/pyscf/pbc/dft/numint.py:91, in eval_ao_kpts(cell, coords, kpts, deriv, relativity, shls_slice, non0tab, cutoff, out, verbose, **kwargs)
#      89 else:
#      90     feval = 'GTOval_sph_deriv%d' % deriv
# ---> 91 return cell.pbc_eval_gto(feval, coords, comp, kpts, shls_slice=shls_slice,
#      92                          non0tab=non0tab, cutoff=cutoff, out=out)
#
# File ~/anaconda3/envs/thc-dev-eugene/lib/python3.9/site-packages/pyscf/pbc/gto/eval_gto.py:146, in eval_gto(cell, eval_name, coords, comp, kpts, kpt, shls_slice, non0tab, ao_loc, cutoff, out, Ls, rcut)
#     144 with cell.with_integral_screen(cutoff):
#     145     drv = getattr(libpbc, eval_name)
# --> 146     drv(ctypes.c_int(ngrids),
#     147         (ctypes.c_int*2)(*shls_slice), ao_loc.ctypes.data_as(ctypes.c_void_p),
#     148         Ls.ctypes.data_as(ctypes.c_void_p), ctypes.c_int(len(Ls)),
#     149         expLk.ctypes.data_as(ctypes.c_void_p), ctypes.c_int(nkpts),
#     150         out.ctypes.data_as(ctypes.c_void_p),
#     151         coords.ctypes.data_as(ctypes.c_void_p),
#     152         rcut.ctypes.data_as(ctypes.c_void_p),
#     153         non0tab.ctypes.data_as(ctypes.c_void_p),
#     154         atm.ctypes.data_as(ctypes.c_void_p), ctypes.c_int(natm),
#     155         bas.ctypes.data_as(ctypes.c_void_p), ctypes.c_int(nbas),
#     156         env.ctypes.data_as(ctypes.c_void_p))
#     158 ao_kpts = []
#     159 for k, kpt in enumerate(kpts_lst):
#
# KeyboardInterrupt:
